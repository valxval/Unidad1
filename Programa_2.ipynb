# %% [markdown]
# <a href="https://colab.research.google.com/github/valxval/Unidad1/blob/main/Programa_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 2. Buscar por software
elif opcion == 2:
  programa = input( "\nIngrese el software que desea buscar: ")
  print("\n--- RESULTADOS ---")
  encontrado = False
  for i in range(len(computadoras)):
    # la funcion (lower)convierte a minuscula el texto, de esta forma nos aseguramos que el texto a buscar y la informacion de las listas este en minuscula y no tengamos problema de que no encuentra un programa este en minuscula y no tengamos problema de que no encuentra un programa porque este escrito de forma diferente usando mayusculas y minusculas
    if programa.lower() in software[i].lower():
      print("ID:", computadoras[i])
      print("Aula:", aulas [i])
      print("Software:", software [i])
      print("Estado:", estados [i])
      encontrado = True

  if encontrado == False:
    print ("No se encontraron computadoras con ese software.")
# Out:
#   File "/tmp/ipykernel_1420/2627663519.py", line 2
#     elif opcion == 2:
#     ^
# SyntaxError: invalid syntax

# %%
#=========================================
# SISTEMA DE PRESTAMOS
# Version 1 - Programacion basica y uso de listas
# ========================================

# Lista de alumnos activos en el sistema
alumnos = [ "26040200", "26040201", "26040202","26040203", "26040204", "26040205", "26040206"]

# Cada valor en la lista de computadoras tiene su lista correspondiente con el aula donde esta ubicada, el software instalado y el estado de esa computadora
computadoras = [ "PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
                "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
                 "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04"]

aulas = [ "LC1", "LC1", "LC1",
        "LC2", "LC2", "LC2",
        "LC3", "LC3", "LC3", "LC3"]

software = [ "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB", "Python, VS Code"]

# %%
estados = [ "Disponible", "Prestada", "Reservada",
           "Disponible", "Prestada", "Reservada",
           "Disponible", "Prestada", "Reservada", "Mantenimiento"]

# MENU PRINCIPAL
# Usamos un ciclo While que se repetira indefinidamente hasta que el usuario teclee la opcion 7 (salir) o cualquier numero superior a 7
opcion = 0
while opcion <= 6:
  print("\n================================")
  print("     SISTEMA DE PRESTAMOS")
  print("================================")
  print("1. Consultar computadoras")
  print("2. Buscar por software")
  print("3. Solicitar prestamo")
  print("4. Devolver computadora")
  print("5. Crear reservacion")
  print("6. Agregar computadora")
  print("7. Salir")
  print("================================")
  opcion = int(input("Ingrese una opcion: "))

# 1. Consultar computadoras
# si el usuario selecciona la opcion 1 se hace un ciclo (for) que recorre toda la lista de computadoras e imprime los valores de las demas listas
if opcion == 1:
    print("\n--- COMPUTADORAS ---")
    for i in range(len(computadoras)):
      print("Aula:", aulas[i])
      print("ID:", computadoras [i])
      print("Software:", software [i])
      print("Estado:", estados [i])
      print("-------------------------")
# Out:
# ================================
#      SISTEMA DE PRESTAMOS
# ================================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservacion
# 6. Agregar computadora
# 7. Salir
# ================================
